# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# ### Plot Training Loss

# %%
# init lists for storing iteration id & training loss

# Cityscapes
iter_v1_cityscapes = []
loss_v1_cityscapes = []

iter_v2_cityscapes = []
loss_v2_cityscapes = []

iter_stdc_cityscapes = []
loss_stdc_cityscapes = []

# PascalVOC
iter_v1_voc = []
loss_v1_voc = []

iter_v2_voc = []
loss_v2_voc = []

iter_stdc_voc = []
loss_stdc_voc = []

# %%
# read CSVs to lists
import csv

# Citycapes
with open('loss/v1_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v1_cityscapes.append(int(row[0]))
        loss_v1_cityscapes.append(float(row[3]))

with open('loss/v2_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v2_cityscapes.append(int(row[0]))
        loss_v2_cityscapes.append(float(row[3]))
        
with open('loss/stdc_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_stdc_cityscapes.append(int(row[0]))
        loss_stdc_cityscapes.append(float(row[3]))

# PascalVOC        
with open('loss/v1_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v1_voc.append(int(row[0]))
        loss_v1_voc.append(float(row[3]))
        
with open('loss/v2_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v2_voc.append(int(row[0]))
        loss_v2_voc.append(float(row[3]))
        
with open('loss/stdc_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_stdc_voc.append(int(row[0]))
        loss_stdc_voc.append(float(row[3]))

# %%
# data smoothing algorithms
import numpy as np

# savgol_filter
from scipy.signal import savgol_filter

# %%
# smooth data by savgol_fiter
SAV_window_size = 301  # set window size
SAV_poly_order = 3  # set polynomial order

# run savgol fiter on training loss

# Cityscapes
SAV_loss_v1_cityscapes = savgol_filter(loss_v1_cityscapes, SAV_window_size, SAV_poly_order)
SAV_loss_v2_cityscapes = savgol_filter(loss_v2_cityscapes, SAV_window_size, SAV_poly_order)
#SAV_loss_stdc_cityscapes = savgol_filter(loss_stdc_cityscapes, SAV_window_size, SAV_poly_order)

# PascalVOC
SAV_loss_v1_voc = savgol_filter(loss_v1_voc, SAV_window_size, SAV_poly_order)
SAV_loss_v2_voc = savgol_filter(loss_v2_voc, SAV_window_size, SAV_poly_order)
#SAV_loss_stdc_voc = savgol_filter(loss_stdc_voc, SAV_window_size_2, SAV_poly_order)

# %%
# plot Cityscapes results with data smoothed by savgol_filter
plt.figure(figsize=(10, 8))
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
plt.plot(iter_v1_cityscapes, SAV_loss_v1_cityscapes, label = 'BisenetV1_Cityscapes')
plt.plot(iter_v2_cityscapes, SAV_loss_v2_cityscapes, label = 'BisenetV2_Cityscapes')
plt.plot(iter_stdc_cityscapes, loss_stdc_cityscapes, label = 'STDC2_Seg50_Cityscapes')

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Iterations', fontsize = 14)
plt.ylabel('Training Loss', fontsize =14)
plt.legend(prop={'size': 12})
plt.savefig('Train_Loss_Cityscapes_Ord3.pdf')
plt.show()

# %%
# plot PascalVOC results with data smoothed by savgol_filter
plt.figure(figsize=(10, 8))
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
plt.plot(iter_v1_voc, SAV_loss_v1_voc, label = 'BisenetV1_VOC')
plt.plot(iter_v2_voc, SAV_loss_v2_voc, label = 'BisenetV2_VOC')
plt.plot(iter_stdc_voc, loss_stdc_voc, label = 'STDC2_Seg50_VOC')


plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Iterations', fontsize = 14)
plt.ylabel('Training Loss', fontsize =14)
plt.legend(prop={'size': 12})
plt.savefig('Train_Loss_VOC_Ord3.pdf')
plt.show()

# %% [markdown]
# ### Plot Accuracy

# %%
# init lists for storing iteration id & accuracy

# Cityscapes
iter_v1_cityscapes = []
acc_v1_cityscapes = []

iter_v2_cityscapes = []
acc_v2_cityscapes = []

iter_stdc_cityscapes = []
acc_stdc_cityscapes = []

# PascalVOC
iter_v1_voc = []
acc_v1_voc = []

iter_v2_voc = []
acc_v2_voc = []

iter_stdc_voc = []
acc_stdc_voc = []

# %%
# read CSVs to lists
import csv

# Citycapes
with open('acc/v1_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v1_cityscapes.append(int(row[0]))
        acc_v1_cityscapes.append(float(row[3]))

with open('acc/v2_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v2_cityscapes.append(int(row[0]))
        acc_v2_cityscapes.append(float(row[3]))
        
with open('acc/stdc_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_stdc_cityscapes.append(int(row[0]))
        acc_stdc_cityscapes.append(float(row[3]))

# PascalVOC        
with open('acc/v1_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v1_voc.append(int(row[0]))
        acc_v1_voc.append(float(row[3]))
        
with open('acc/v2_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v2_voc.append(int(row[0]))
        acc_v2_voc.append(float(row[3]))
        
with open('acc/stdc_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_stdc_voc.append(int(row[0]))
        acc_stdc_voc.append(float(row[3]))

# %%
# plot Cityscapes results
plt.figure(figsize=(10, 8))
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
plt.plot(iter_v1_cityscapes, acc_v1_cityscapes, label = 'BisenetV1_Cityscapes')
plt.plot(iter_v2_cityscapes, acc_v2_cityscapes, label = 'BisenetV2_Cityscapes')
plt.plot(iter_stdc_cityscapes, acc_stdc_cityscapes, label = 'STDC2_Seg50_Cityscapes')

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize =14)
plt.legend(prop={'size': 12})
plt.savefig('ACC_Cityscapes.pdf')
plt.show()

# %%
# plot PascalVOC results
plt.figure(figsize=(10, 8))
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
plt.plot(iter_v1_voc, acc_v1_voc, label = 'BisenetV1_VOC')
plt.plot(iter_v2_voc, acc_v2_voc, label = 'BisenetV2_VOC')
plt.plot(iter_stdc_voc, acc_stdc_voc, label = 'STDC2_Seg50_VOC')


plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize =14)
plt.legend(prop={'size': 12})
plt.savefig('ACC_VOC.pdf')
plt.show()

# %% [markdown]
# ### Plot Mean Intersection over Union (MIoU)

# %%
# init lists for storing iteration id & MIoU

# Cityscapes
iter_v1_cityscapes = []
miou_v1_cityscapes = []

iter_v2_cityscapes = []
miou_v2_cityscapes = []

iter_stdc_cityscapes = []
miou_stdc_cityscapes = []

# PascalVOC
iter_v1_voc = []
miou_v1_voc = []

iter_v2_voc = []
miou_v2_voc = []

iter_stdc_voc = []
miou_stdc_voc = []

# %%
# read CSVs to lists
import csv

# Citycapes
with open('miou/v1_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v1_cityscapes.append(int(row[0]))
        miou_v1_cityscapes.append(float(row[3]))

with open('miou/v2_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v2_cityscapes.append(int(row[0]))
        miou_v2_cityscapes.append(float(row[3]))
        
with open('miou/stdc_cityscapes.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_stdc_cityscapes.append(int(row[0]))
        miou_stdc_cityscapes.append(float(row[3]))

# PascalVOC        
with open('miou/v1_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v1_voc.append(int(row[0]))
        miou_v1_voc.append(float(row[3]))
        
with open('miou/v2_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_v2_voc.append(int(row[0]))
        miou_v2_voc.append(float(row[3]))
        
with open('miou/stdc_voc.csv')as f:
    f_csv = csv.reader(f)
    headings = next(f_csv)
    for row in f_csv:
        iter_stdc_voc.append(int(row[0]))
        miou_stdc_voc.append(float(row[3]))

# %%
# plot Cityscapes
plt.figure(figsize=(10, 8))
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
plt.plot(iter_v1_cityscapes, miou_v1_cityscapes, label = 'BisenetV1_Cityscapes')
plt.plot(iter_v2_cityscapes, miou_v2_cityscapes, label = 'BisenetV2_Cityscapes')
plt.plot(iter_stdc_cityscapes, miou_stdc_cityscapes, label = 'STDC2_Seg50_Cityscapes')

plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Iterations', fontsize = 14)
plt.ylabel('Mean IoU', fontsize =14)
plt.legend(prop={'size': 12})
plt.savefig('MIOU_Cityscapes.pdf')
plt.show()

# %%
# plot PascalVOC results
plt.figure(figsize=(10, 8))
plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)
plt.plot(iter_v1_voc, miou_v1_voc, label = 'BisenetV1_VOC')
plt.plot(iter_v2_voc, miou_v2_voc, label = 'BisenetV2_VOC')
plt.plot(iter_stdc_voc, miou_stdc_voc, label = 'STDC2_Seg50_VOC')


plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.xlabel('Iterations', fontsize = 14)
plt.ylabel('Mean IoU', fontsize =14)
plt.legend(prop={'size': 12})
plt.savefig('MIOU_VOC.pdf')
plt.show()
